# %% [markdown]
# <a href="https://colab.research.google.com/github/ArasyH/ArasyH.github.io/blob/main/Paccman_IntroductiontoDataScraping_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 1: API Scraping Exchange Rates

# %%
# Import library
import requests

# Where USD is the base currency you want to use
# Change 'YOUR_API_KEY' with Your API KEY
url = ''

# Making our request
response = requests.get(url)
data = response.json()

# Your JSON object
data
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1733184002,
#  'time_last_update_utc': 'Tue, 03 Dec 2024 00:00:02 +0000',
#  'time_next_update_unix': 1733270402,
#  'time_next_update_utc': 'Wed, 04 Dec 2024 00:00:02 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 68.139,
#   'ALL': 93.2605,
#   'AMD': 397.9336,
#   'ANG': 1.79,
#   'AOA': 920.6479,
#   'ARS': 1011.92,
#   'AUD': 1.5444,
#   'AWG': 1.79,
#   'AZN': 1.7002,
#   'BAM': 1.8627,
#   'BBD': 2.0,
#   'BDT': 119.5029,
#   'BGN': 1.8625,
#   'BHD': 0.376,
#   'BIF': 2932.6185,
#   'BMD': 1.0,
#   'BND': 1.3453,
#   'BOB': 6.9088,
#   'BRL': 6.0179,
#   'BSD': 1.0,
#   'BTN': 84.744,
#   'BWP': 13.6673,
#   'BYN': 3.2708,
#   'BZD': 2.0,
#   'CAD': 1.4045,
#   'CDF': 2854.8756,
#   'CHF': 0.8863,
#   'CLP': 973.6629,
#   'CNY': 7.2783,
#   'COP': 4442.2051,
#   'CRC': 508.1753,
#   'CUP': 24.0,
#   'CVE': 105.0126,
#   'CZK': 24.0421,
#   'DJF': 177.721,
#   'DKK': 7.105,
#   'DOP': 60.3247,
#   'DZD': 133.5461,
#   'EGP': 49.7152,
#   'ERN': 15.0,
#   'ETB': 123.8572,
#   'EUR': 0.9523,
#   'FJD': 2.2687,
#   'FKP': 0.7897,
#   'FOK': 7.1053,
#   'GBP': 0.7897,
#   'GEL': 2.8472,
#   'GGP': 0.7897,
#   'GHS': 15.2311,
#   'GIP': 0.7897,
#   'GMD': 71.8795,
#   'GNF': 8584.2033,
#   'GTQ': 7.7228,
#   'GYD': 209.16,
#   'HKD': 7.7817,
#   'HNL': 25.3022,
#   'HRK': 7.1756,
#   'HTG': 131.0856,
#   'HUF': 394.7914,
#   'IDR': 15925.7827,
#   'ILS': 3.6453,
#   'IMP': 0.7897,
#   'INR': 84.7498,
#   'IQD': 1312.9051,
#   'IRR': 41940.4885,
#   'ISK': 138.7479,
#   'JEP': 0.7897,
#   'JMD': 157.0276,
#   'JOD': 0.709,
#   'JPY': 149.7151,
#   'KES': 129.745,
#   'KGS': 86.8492,
#   'KHR': 4041.9782,
#   'KID': 1.5444,
#   'KMF': 468.5334,
#   'KRW': 1405.0759,
#   'KWD': 0.3074,
#   'KYD': 0.8333,
#   'KZT': 525.2612,
#   'LAK': 21935.7612,
#   'LBP': 89500.0,
#   'LKR': 290.5232,
#   'LRD': 179.1979,
#   'LSL': 18.1568,
#   'LYD': 4.8687,
#   'MAD': 10.0236,
#   'MDL': 18.2964,
#   'MGA': 4656.0152,
#   'MKD': 58.2997,
#   'MMK': 2102.2724,
#   'MNT': 3426.8576,
#   'MOP': 8.0151,
#   'MRU': 39.8949,
#   'MUR': 46.5232,
#   'MVR': 15.4503,
#   'MWK': 1744.2329,
#   'MXN': 20.4239,
#   'MYR': 4.4585,
#   'MZN': 63.9743,
#   'NAD': 18.1568,
#   'NGN': 1674.4247,
#   'NIO': 36.7964,
#   'NOK': 11.0982,
#   'NPR': 135.5903,
#   'NZD': 1.6992,
#   'OMR': 0.3845,
#   'PAB': 1.0,
#   'PEN': 3.7555,
#   'PGK': 4.0178,
#   'PHP': 58.6855,
#   'PKR': 277.8993,
#   'PLN': 4.0817,
#   'PYG': 7843.0574,
#   'QAR': 3.64,
#   'RON': 4.7355,
#   'RSD': 111.4274,
#   'RUB': 106.29,
#   'RWF': 1387.7792,
#   'SAR': 3.75,
#   'SBD': 8.5122,
#   'SCR': 14.4144,
#   'SDG': 454.4825,
#   'SEK': 10.9892,
#   'SGD': 1.3453,
#   'SHP': 0.7897,
#   'SLE': 22.7323,
#   'SLL': 22732.2912,
#   'SOS': 571.1184,
#   'SRD': 35.5172,
#   'SSP': 3697.3784,
#   'STN': 23.333,
#   'SYP': 12920.007,
#   'SZL': 18.1568,
#   'THB': 34.4824,
#   'TJS': 10.7895,
#   'TMT': 3.5,
#   'TND': 3.1584,
#   'TOP': 2.3771,
#   'TRY': 34.7458,
#   'TTD': 6.7518,
#   'TVD': 1.5444,
#   'TWD': 32.6052,
#   'TZS': 2640.1075,
#   'UAH': 41.6789,
#   'UGX': 3694.2429,
#   'UYU': 43.0837,
#   'UZS': 12836.6369,
#   'VES': 47.7293,
#   'VND': 25380.762,
#   'VUV': 118.6194,
#   'WST': 2.772,
#   'XAF': 624.7112,
#   'XCD': 2.7,
#   'XDR': 0.7619,
#   'XOF': 624.7112,
#   'XPF': 113.6477,
#   'YER': 249.7825,
#   'ZAR': 18.1483,
#   'ZMW': 26.9418,
#   'ZWL': 25.5672}}

# %%
# Import library
import pandas as pd

# %%
# Merubah json ke dataframe
data = pd.json_normalize(data)
data.head()
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1733184002
#
#               time_last_update_utc  time_next_update_unix  \
# 0  Tue, 03 Dec 2024 00:00:02 +0000             1733270402
#
#               time_next_update_utc base_code  conversion_rates.USD  \
# 0  Wed, 04 Dec 2024 00:00:02 +0000       USD                     1
#
#    conversion_rates.AED  ...  conversion_rates.WST  conversion_rates.XAF  \
# 0                3.6725  ...                 2.772              624.7112
#
#    conversion_rates.XCD  conversion_rates.XDR  conversion_rates.XOF  \
# 0                   2.7                0.7619              624.7112
#
#    conversion_rates.XPF  conversion_rates.YER  conversion_rates.ZAR  \
# 0              113.6477              249.7825               18.1483
#
#    conversion_rates.ZMW  conversion_rates.ZWL
# 0               26.9418               25.5672
#
# [1 rows x 170 columns]

# %%
# Mengecek column dan jumlahnya
data.columns
# Out:
# Index(['result', 'documentation', 'terms_of_use', 'time_last_update_unix',
#        'time_last_update_utc', 'time_next_update_unix', 'time_next_update_utc',
#        'base_code', 'conversion_rates.USD', 'conversion_rates.AED',
#        ...
#        'conversion_rates.WST', 'conversion_rates.XAF', 'conversion_rates.XCD',
#        'conversion_rates.XDR', 'conversion_rates.XOF', 'conversion_rates.XPF',
#        'conversion_rates.YER', 'conversion_rates.ZAR', 'conversion_rates.ZMW',
#        'conversion_rates.ZWL'],
#       dtype='object', length=170)

# %%
# Mengambil 8 kolom pertama
data1 = data.iloc[:, 0:8]
data1.head()
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1733184002
#
#               time_last_update_utc  time_next_update_unix  \
# 0  Tue, 03 Dec 2024 00:00:02 +0000             1733270402
#
#               time_next_update_utc base_code
# 0  Wed, 04 Dec 2024 00:00:02 +0000       USD

# %%
data1['key'] = 1
data1.head()
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1733184002
#
#               time_last_update_utc  time_next_update_unix  \
# 0  Tue, 03 Dec 2024 00:00:02 +0000             1733270402
#
#               time_next_update_utc base_code  key
# 0  Wed, 04 Dec 2024 00:00:02 +0000       USD    1

# %%
data1['time_last_update_utc'] = pd.to_datetime(data['time_last_update_utc'])
data1
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1733184002
#
#        time_last_update_utc  time_next_update_unix  \
# 0 2024-12-03 00:00:02+00:00             1733270402
#
#               time_next_update_utc base_code  key
# 0  Wed, 04 Dec 2024 00:00:02 +0000       USD    1

# %%
# from pytz import timezone
# wib = timezone('Asia/Jakarta')
# data1['time_last_update_utc'] = data1['time_last_update_utc'].astimezone(timezone('Asia/jakarta'))

# %%
# Mengambil kolom ke 9 - 170 untuk kemudian di transpose
data2 = data.iloc[:,8:].T
data2.head()
# Out:
#                              0
# conversion_rates.USD    1.0000
# conversion_rates.AED    3.6725
# conversion_rates.AFN   68.1390
# conversion_rates.ALL   93.2605
# conversion_rates.AMD  397.9336

# %%
# Menambah kolom baru 'key'
data2['key'] = 1
data2.head()
# Out:
#                              0  key
# conversion_rates.USD    1.0000    1
# conversion_rates.AED    3.6725    1
# conversion_rates.AFN   68.1390    1
# conversion_rates.ALL   93.2605    1
# conversion_rates.AMD  397.9336    1

# %%
# Merubah nama kolom '0' menjadi 'rate'
data2 = data2.rename(columns={0:'rate'})
data2.head()
# Out:
#                           rate  key
# conversion_rates.USD    1.0000    1
# conversion_rates.AED    3.6725    1
# conversion_rates.AFN   68.1390    1
# conversion_rates.ALL   93.2605    1
# conversion_rates.AMD  397.9336    1

# %%
# Merubah index menjadi column dengan nama 'currency'
data2['currency'] = data2.index
data2.head()
# Out:
#                           rate  key              currency
# conversion_rates.USD    1.0000    1  conversion_rates.USD
# conversion_rates.AED    3.6725    1  conversion_rates.AED
# conversion_rates.AFN   68.1390    1  conversion_rates.AFN
# conversion_rates.ALL   93.2605    1  conversion_rates.ALL
# conversion_rates.AMD  397.9336    1  conversion_rates.AMD

# %%
# Menghapus karakter 'conversion_rates.' di kolom currency
data2['currency'] = data2['currency'].str.replace(r'conversion_rates.', '', regex=True)
data2.head()
# Out:
#                           rate  key currency
# conversion_rates.USD    1.0000    1      USD
# conversion_rates.AED    3.6725    1      AED
# conversion_rates.AFN   68.1390    1      AFN
# conversion_rates.ALL   93.2605    1      ALL
# conversion_rates.AMD  397.9336    1      AMD

# %%
# Merubah posisi kolom
data2 = data2[['key','currency','rate']]
# Menghapus index
data2.reset_index(drop=True, inplace=True)
data2.head()
# Out:
#    key currency      rate
# 0    1      USD    1.0000
# 1    1      AED    3.6725
# 2    1      AFN   68.1390
# 3    1      ALL   93.2605
# 4    1      AMD  397.9336

# %%
data_merged = pd.merge(data1, data2, on='key')

# %%
data_merged.head()
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
# 1  success  https://www.exchangerate-api.com/docs
# 2  success  https://www.exchangerate-api.com/docs
# 3  success  https://www.exchangerate-api.com/docs
# 4  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1733184002
# 1  https://www.exchangerate-api.com/terms             1733184002
# 2  https://www.exchangerate-api.com/terms             1733184002
# 3  https://www.exchangerate-api.com/terms             1733184002
# 4  https://www.exchangerate-api.com/terms             1733184002
#
#        time_last_update_utc  time_next_update_unix  \
# 0 2024-12-03 00:00:02+00:00             1733270402
# 1 2024-12-03 00:00:02+00:00             1733270402
# 2 2024-12-03 00:00:02+00:00             1733270402
# 3 2024-12-03 00:00:02+00:00             1733270402
# 4 2024-12-03 00:00:02+00:00             1733270402
#
#               time_next_update_utc base_code  key currency      rate
# 0  Wed, 04 Dec 2024 00:00:02 +0000       USD    1      USD    1.0000
# 1  Wed, 04 Dec 2024 00:00:02 +0000       USD    1      AED    3.6725
# 2  Wed, 04 Dec 2024 00:00:02 +0000       USD    1      AFN   68.1390
# 3  Wed, 04 Dec 2024 00:00:02 +0000       USD    1      ALL   93.2605
# 4  Wed, 04 Dec 2024 00:00:02 +0000       USD    1      AMD  397.9336

# %%
data_merged = data_merged[['time_last_update_utc','base_code','currency','rate']]
data_merged.head()
# Out:
#        time_last_update_utc base_code currency      rate
# 0 2024-12-03 00:00:02+00:00       USD      USD    1.0000
# 1 2024-12-03 00:00:02+00:00       USD      AED    3.6725
# 2 2024-12-03 00:00:02+00:00       USD      AFN   68.1390
# 3 2024-12-03 00:00:02+00:00       USD      ALL   93.2605
# 4 2024-12-03 00:00:02+00:00       USD      AMD  397.9336
