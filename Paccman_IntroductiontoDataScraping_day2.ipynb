# %% [markdown]
# <a href="https://colab.research.google.com/github/ArasyH/ArasyH.github.io/blob/main/Paccman_IntroductiontoDataScraping_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 1: API Scraping Exchange Rates

# %%
# Import library
import requests

# Where USD is the base currency you want to use
# Change 'YOUR_API_KEY' with Your API KEY
url = 'https://v6.exchangerate-api.com/v6/12838347eab73185768f8c35/latest/USD'

# Making our request
response = requests.get(url)
data = response.json()

# Your JSON object
data
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1714003202,
#  'time_last_update_utc': 'Thu, 25 Apr 2024 00:00:02 +0000',
#  'time_next_update_unix': 1714089602,
#  'time_next_update_utc': 'Fri, 26 Apr 2024 00:00:02 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 72.1295,
#   'ALL': 94.2989,
#   'AMD': 391.3023,
#   'ANG': 1.79,
#   'AOA': 843.5736,
#   'ARS': 864.75,
#   'AUD': 1.5393,
#   'AWG': 1.79,
#   'AZN': 1.7004,
#   'BAM': 1.8285,
#   'BBD': 2.0,
#   'BDT': 109.7343,
#   'BGN': 1.8287,
#   'BHD': 0.376,
#   'BIF': 2854.2739,
#   'BMD': 1.0,
#   'BND': 1.3618,
#   'BOB': 6.9218,
#   'BRL': 5.1426,
#   'BSD': 1.0,
#   'BTN': 83.3524,
#   'BWP': 13.879,
#   'BYN': 3.2651,
#   'BZD': 2.0,
#   'CAD': 1.3698,
#   'CDF': 2763.1635,
#   'CHF': 0.9141,
#   'CLP': 955.5221,
#   'CNY': 7.2583,
#   'COP': 3903.6353,
#   'CRC': 501.373,
#   'CUP': 24.0,
#   'CVE': 103.0889,
#   'CZK': 23.6175,
#   'DJF': 177.721,
#   'DKK': 6.9739,
#   'DOP': 58.6698,
#   'DZD': 134.4426,
#   'EGP': 47.9036,
#   'ERN': 15.0,
#   'ETB': 56.9434,
#   'EUR': 0.9349,
#   'FJD': 2.2942,
#   'FKP': 0.8028,
#   'FOK': 6.9738,
#   'GBP': 0.8028,
#   'GEL': 2.6909,
#   'GGP': 0.8028,
#   'GHS': 13.5323,
#   'GIP': 0.8028,
#   'GMD': 66.9901,
#   'GNF': 8585.6609,
#   'GTQ': 7.7709,
#   'GYD': 209.3496,
#   'HKD': 7.8324,
#   'HNL': 24.7109,
#   'HRK': 7.0442,
#   'HTG': 132.4259,
#   'HUF': 368.2373,
#   'IDR': 16177.4236,
#   'ILS': 3.781,
#   'IMP': 0.8028,
#   'INR': 83.3525,
#   'IQD': 1310.0581,
#   'IRR': 42032.8038,
#   'ISK': 140.6429,
#   'JEP': 0.8028,
#   'JMD': 155.8933,
#   'JOD': 0.709,
#   'JPY': 155.1276,
#   'KES': 134.3174,
#   'KGS': 89.08,
#   'KHR': 4056.1375,
#   'KID': 1.5393,
#   'KMF': 459.9502,
#   'KRW': 1375.231,
#   'KWD': 0.308,
#   'KYD': 0.8333,
#   'KZT': 444.1619,
#   'LAK': 21574.413,
#   'LBP': 89500.0,
#   'LKR': 298.1722,
#   'LRD': 193.1642,
#   'LSL': 19.2142,
#   'LYD': 4.8811,
#   'MAD': 10.1472,
#   'MDL': 17.8705,
#   'MGA': 4411.9303,
#   'MKD': 57.6797,
#   'MMK': 2100.9075,
#   'MNT': 3370.3975,
#   'MOP': 8.0674,
#   'MRU': 39.7178,
#   'MUR': 46.498,
#   'MVR': 15.4438,
#   'MWK': 1740.5979,
#   'MXN': 17.081,
#   'MYR': 4.7778,
#   'MZN': 64.0485,
#   'NAD': 19.2142,
#   'NGN': 1233.3443,
#   'NIO': 36.7775,
#   'NOK': 10.9943,
#   'NPR': 133.3639,
#   'NZD': 1.6853,
#   'OMR': 0.3845,
#   'PAB': 1.0,
#   'PEN': 3.7099,
#   'PGK': 3.7985,
#   'PHP': 57.6396,
#   'PKR': 278.5955,
#   'PLN': 4.0488,
#   'PYG': 7433.9341,
#   'QAR': 3.64,
#   'RON': 4.6566,
#   'RSD': 109.5945,
#   'RUB': 92.4573,
#   'RWF': 1295.8513,
#   'SAR': 3.75,
#   'SBD': 8.4232,
#   'SCR': 13.6897,
#   'SDG': 544.3411,
#   'SEK': 10.8846,
#   'SGD': 1.3617,
#   'SHP': 0.8028,
#   'SLE': 22.6572,
#   'SLL': 22657.164,
#   'SOS': 571.7297,
#   'SRD': 34.2667,
#   'SSP': 1587.3751,
#   'STN': 22.9055,
#   'SYP': 12946.4282,
#   'SZL': 19.2142,
#   'THB': 37.0444,
#   'TJS': 10.927,
#   'TMT': 3.5017,
#   'TND': 3.149,
#   'TOP': 2.3584,
#   'TRY': 32.5848,
#   'TTD': 6.7738,
#   'TVD': 1.5393,
#   'TWD': 32.6097,
#   'TZS': 2589.4849,
#   'UAH': 39.4863,
#   'UGX': 3811.4782,
#   'UYU': 38.4771,
#   'UZS': 12733.726,
#   'VES': 36.4231,
#   'VND': 25384.9866,
#   'VUV': 121.8112,
#   'WST': 2.7649,
#   'XAF': 613.267,
#   'XCD': 2.7,
#   'XDR': 0.7602,
#   'XOF': 613.267,
#   'XPF': 111.5658,
#   'YER': 250.2056,
#   'ZAR': 19.2141,
#   'ZMW': 26.0915,
#   'ZWL': 13.2517}}

# %%
# Import library
import pandas as pd

# %%
# Merubah json ke dataframe
data = pd.json_normalize(data)
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-77633e394967> in <cell line: 2>()
#       1 # Merubah json ke dataframe
# ----> 2 data = pd.json_normalize(data)
#       3 data.head()
#
# NameError: name 'data' is not defined

# %%
# Mengecek column dan jumlahnya
data.columns
# Out:
# Index(['result', 'documentation', 'terms_of_use', 'time_last_update_unix',
#        'time_last_update_utc', 'time_next_update_unix', 'time_next_update_utc',
#        'base_code', 'conversion_rates.USD', 'conversion_rates.AED',
#        ...
#        'conversion_rates.WST', 'conversion_rates.XAF', 'conversion_rates.XCD',
#        'conversion_rates.XDR', 'conversion_rates.XOF', 'conversion_rates.XPF',
#        'conversion_rates.YER', 'conversion_rates.ZAR', 'conversion_rates.ZMW',
#        'conversion_rates.ZWL'],
#       dtype='object', length=170)

# %%
# Mengambil 8 kolom pertama
data1 = data.iloc[:, 0:8]
data1.head()
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1713024001
#
#               time_last_update_utc  time_next_update_unix  \
# 0  Sat, 13 Apr 2024 16:00:01 +0000             1713027601
#
#               time_next_update_utc base_code
# 0  Sat, 13 Apr 2024 17:00:01 +0000       USD

# %%
data1['key'] = 1
data1.head()
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1713024001
#
#               time_last_update_utc  time_next_update_unix  \
# 0  Sat, 13 Apr 2024 16:00:01 +0000             1713027601
#
#               time_next_update_utc base_code  key
# 0  Sat, 13 Apr 2024 17:00:01 +0000       USD    1

# %%
data1['time_last_update_utc'] = pd.to_datetime(data['time_last_update_utc'])
data1
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1713024001
#
#        time_last_update_utc  time_next_update_unix  \
# 0 2024-04-13 16:00:01+00:00             1713027601
#
#               time_next_update_utc base_code  key
# 0  Sat, 13 Apr 2024 17:00:01 +0000       USD    1

# %%
# from pytz import timezone
# wib = timezone('Asia/Jakarta')
# data1['time_last_update_utc'] = data1['time_last_update_utc'].astimezone(timezone('Asia/jakarta'))

# %%
# Mengambil kolom ke 9 - 170 untuk kemudian di transpose
data2 = data.iloc[:,8:].T
data2.head()
# Out:
#                                0
# conversion_rates.USD    1.000000
# conversion_rates.AED    3.672500
# conversion_rates.AFN   71.512189
# conversion_rates.ALL   94.239990
# conversion_rates.AMD  393.146414

# %%
# Menambah kolom baru 'key'
data2['key'] = 1
data2.head()
# Out:
#                                0  key
# conversion_rates.USD    1.000000    1
# conversion_rates.AED    3.672500    1
# conversion_rates.AFN   71.512189    1
# conversion_rates.ALL   94.239990    1
# conversion_rates.AMD  393.146414    1

# %%
# Merubah nama kolom '0' menjadi 'rate'
data2 = data2.rename(columns={0:'rate'})
data2.head()
# Out:
#                             rate  key
# conversion_rates.USD    1.000000    1
# conversion_rates.AED    3.672500    1
# conversion_rates.AFN   71.512189    1
# conversion_rates.ALL   94.239990    1
# conversion_rates.AMD  393.146414    1

# %%
# Merubah index menjadi column dengan nama 'currency'
data2['currency'] = data2.index
data2.head()
# Out:
#                             rate  key              currency
# conversion_rates.USD    1.000000    1  conversion_rates.USD
# conversion_rates.AED    3.672500    1  conversion_rates.AED
# conversion_rates.AFN   71.512189    1  conversion_rates.AFN
# conversion_rates.ALL   94.239990    1  conversion_rates.ALL
# conversion_rates.AMD  393.146414    1  conversion_rates.AMD

# %%
# Menghapus karakter 'conversion_rates.' di kolom currency
data2['currency'] = data2['currency'].str.replace(r'conversion_rates.', '', regex=True)
data2.head()
# Out:
#                             rate  key currency
# conversion_rates.USD    1.000000    1      USD
# conversion_rates.AED    3.672500    1      AED
# conversion_rates.AFN   71.512189    1      AFN
# conversion_rates.ALL   94.239990    1      ALL
# conversion_rates.AMD  393.146414    1      AMD

# %%
# Merubah posisi kolom
data2 = data2[['key','currency','rate']]
# Menghapus index
data2.reset_index(drop=True, inplace=True)
data2.head()
# Out:
#    key currency        rate
# 0    1      USD    1.000000
# 1    1      AED    3.672500
# 2    1      AFN   71.512189
# 3    1      ALL   94.239990
# 4    1      AMD  393.146414

# %%
data_merged = pd.merge(data1, data2, on='key')

# %%
data_merged.head()
# Out:
#     result                          documentation  \
# 0  success  https://www.exchangerate-api.com/docs
# 1  success  https://www.exchangerate-api.com/docs
# 2  success  https://www.exchangerate-api.com/docs
# 3  success  https://www.exchangerate-api.com/docs
# 4  success  https://www.exchangerate-api.com/docs
#
#                              terms_of_use  time_last_update_unix  \
# 0  https://www.exchangerate-api.com/terms             1713024001
# 1  https://www.exchangerate-api.com/terms             1713024001
# 2  https://www.exchangerate-api.com/terms             1713024001
# 3  https://www.exchangerate-api.com/terms             1713024001
# 4  https://www.exchangerate-api.com/terms             1713024001
#
#        time_last_update_utc  time_next_update_unix  \
# 0 2024-04-13 16:00:01+00:00             1713027601
# 1 2024-04-13 16:00:01+00:00             1713027601
# 2 2024-04-13 16:00:01+00:00             1713027601
# 3 2024-04-13 16:00:01+00:00             1713027601
# 4 2024-04-13 16:00:01+00:00             1713027601
#
#               time_next_update_utc base_code  key currency        rate
# 0  Sat, 13 Apr 2024 17:00:01 +0000       USD    1      USD    1.000000
# 1  Sat, 13 Apr 2024 17:00:01 +0000       USD    1      AED    3.672500
# 2  Sat, 13 Apr 2024 17:00:01 +0000       USD    1      AFN   71.512189
# 3  Sat, 13 Apr 2024 17:00:01 +0000       USD    1      ALL   94.239990
# 4  Sat, 13 Apr 2024 17:00:01 +0000       USD    1      AMD  393.146414

# %%
data_merged = data_merged[['time_last_update_utc','base_code','currency','rate']]
data_merged.head()
# Out:
#        time_last_update_utc base_code currency        rate
# 0 2024-04-13 16:00:01+00:00       USD      USD    1.000000
# 1 2024-04-13 16:00:01+00:00       USD      AED    3.672500
# 2 2024-04-13 16:00:01+00:00       USD      AFN   71.512189
# 3 2024-04-13 16:00:01+00:00       USD      ALL   94.239990
# 4 2024-04-13 16:00:01+00:00       USD      AMD  393.146414
